# %%
1+1
# Out:
# 2

# %%
2^3
# Out:
# 1

# %%
7/3
# Out:
# 2.3333333333333335

# %%
2**3
# Out:
# 8

# %%
2000*0.05*150
# Out:
# 15000.0

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot([-2, 10, 3, 13, 5])

# %%
randn(10)
# Out:
# array([-1.00506463,  2.23163539, -0.89187412,  0.30526819, -0.14556331,
#         0.69732641, -0.21639846,  0.13311121, -0.42826194, -0.43526212])

# %%
plot(randn(10))

# %%
plot(randn(100))

# %%
plot([-2,1,2.7,3.3],[3,-5,6,0])
